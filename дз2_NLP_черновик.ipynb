# %% [markdown]
# <a href="https://colab.research.google.com/github/flash-berry/NLP/blob/main/%D0%B4%D0%B72_NLP_%D1%87%D0%B5%D1%80%D0%BD%D0%BE%D0%B2%D0%B8%D0%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Изменения:
#
# 1) Алгоритм токенизации пар байтов - Byte pair encoding

# %%
import zipfile
import os

zip_path = '/content/texts.zip'

extract_dir = 'extract_dir'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall(extract_dir)

txt_files = [f for f in os.listdir(extract_dir) if f.endswith('.txt')]

text = ''
for file in txt_files:
  file_path = os.path.join(extract_dir, file)
  with open(file_path, 'r', encoding='utf-8') as f:
    text += f.read()

# %%
print(text[:100])
# Out:
# «Внимай, что я тебе вещаю:
# Я телом евнух, муж душой». —
# «Но что ж ты делаешь со мной?» —
# «Я тело в д

# %%
tokens = list(map(int, text.encode("utf-8")))
print(len(tokens))
# Out:
# 1272984

# %% [markdown]
# МОЙ КОД

# %%
import regex as re

advanced_russian_pat = re.compile(
    r"""
    # Английские клитики (можно удалить, если работаем только с русским)
    's|'t|'re|'ve|'m|'ll|'d|

    # Русские слова с апострофами и дефисами ("кой-какой", "чудо-юдо")
    (?:[ёЁа-яА-Я]+(?:['-][ёЁа-яА-Я]+)*)|

    # Сокращения ("т.д.", "т.п.", "и.о.")
    (?:[ёЁа-яА-Я]\.){1,3}|

    # Числа (включая числа с разделителями: 1_000_000, 1,234)
    \d+(?:[_,]\d+)*|

    # Остальные последовательности символов (знаки препинания, символы и т.д.)
    [^\sёЁа-яА-Я\d]+|

    # Пробелы (но не перед другим пробелом)
    \s+(?!\S)|

    # Любые оставшиеся пробелы
    \s+
    """,
    re.VERBOSE | re.IGNORECASE
)

# %%
tokens = re.findall(advanced_russian_pat, text)
len(tokens)

tton = [] #tokens to numbers size: number tokens x size tokens
for i in range(len(tokens)):
  tton.append(list(map(int, tokens[i].encode("utf-8"))))

def get_stats(tton):
    counts = {}
    for i in range(len(tton)):
      for j in range(len(tton[i])-1):
          pair = (tton[i][j], tton[i][j+1])
          counts[pair] = counts.get(pair, 0) + 1
    return counts

stats = get_stats(tton)

# %%
top_pair = max(stats, key=stats.get)
print(top_pair)
# Out:
# (208, 190)

# %%
stats[208,190]
# Out:
# 51568

# %%
chr(208), chr(190)
# Out:
# ('Ð', '¾')

# %%
def merge(tton, pair, idx):
  newids = []

  for i in range(len(tton)):
    newids.append([])
    j = 0
    while j < len(tton[i]):
      if j < len(tton[i]) - 1 and tton[i][j] == pair[0] and tton[i][j+1] == pair[1]:
        newids[i].append(idx)
        j += 2
      else:
        newids[i].append(tton[i][j])
        j += 1
  return newids

tokens2 = merge(tton, top_pair, 256)
print(len(tokens2))
# Out:
# 263637

# %%
import copy

vocab_size = 276
num_merge = vocab_size - 256
ids = copy.deepcopy(tton)

merges = {}
for i in range(num_merge):
  stats = get_stats(ids)
  pair = max(stats, key = stats.get)
  idx = 256 + i
  print(f'merging {pair} into a new token {idx}')
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (208, 190) into a new token 256
# merging (208, 181) into a new token 257
# merging (208, 176) into a new token 258
# merging (208, 189) into a new token 259
# merging (208, 184) into a new token 260
# merging (209, 130) into a new token 261
# merging (256, 208) into a new token 262
# merging (209, 129) into a new token 263
# merging (209, 128) into a new token 264
# merging (208, 187) into a new token 265
# merging (208, 178) into a new token 266
# merging (209, 131) into a new token 267
# merging (208, 180) into a new token 268
# merging (208, 188) into a new token 269
# merging (209, 139) into a new token 270
# merging (208, 186) into a new token 271
# merging (209, 140) into a new token 272
# merging (208, 191) into a new token 273
# merging (209, 143) into a new token 274
# merging (208, 177) into a new token 275

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors = "replace")
  return text

print(decode([128]))
# Out:
# �

# %%
from itertools import chain

def encode(text):

    tokens = re.findall(advanced_russian_pat, text)
    tton = [] #tokens to numbers size: number tokens x size tokens
    for i in range(len(tokens)):
      tton.append(list(map(int, tokens[i].encode("utf-8"))))

    while True:
        # Находим самую частую пару
        pairs = get_stats(tton)
        if not pairs:
            break
        # Ищем первую пару, которая есть в нашем словаре merges
        pair = None
        for p in pairs:
            if p in merges:
                pair = p
                break
        if not pair:
            break  # нет больше пар для замены
        idx = merges[pair]
        # Заменяем все вхождения пары в tokens
        tton = merge(tton, pair, idx)

    return list(chain.from_iterable(tton))

# %%
text2 = decode(encode(text))
print(text2 == text)
# Out:
# True

# %% [markdown]
# КОНЕЦ КОДА

# %%
print(tokens[:100])
# Out:
# [194, 171, 208, 146, 208, 189, 208, 184, 208, 188, 208, 176, 208, 185, 44, 32, 209, 135, 209, 130, 208, 190, 32, 209, 143, 32, 209, 130, 208, 181, 208, 177, 208, 181, 32, 208, 178, 208, 181, 209, 137, 208, 176, 209, 142, 58, 10, 208, 175, 32, 209, 130, 208, 181, 208, 187, 208, 190, 208, 188, 32, 208, 181, 208, 178, 208, 189, 209, 131, 209, 133, 44, 32, 208, 188, 209, 131, 208, 182, 32, 208, 180, 209, 131, 209, 136, 208, 190, 208, 185, 194, 187, 46, 32, 226, 128, 148, 10, 194, 171]

# %%
def get_stats(tokens):
    counts = {}
    for i in range(len(tokens)-1):
        pair = (tokens[i], tokens[i+1])
        counts[pair] = counts.get(pair, 0) + 1
    return counts

stats = get_stats(tokens)

top_pair = max(stats, key = stats.get)
top_pair
# Out:
# (32, 208)

# %%
def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

tokens2 = merge(tokens, top_pair, 256)
print(len(tokens2))
# Out:
# 1211391

# %%
vocab_size = 276
num_merge = vocab_size - 256
ids = list(tokens)

merges = {}
for i in range(num_merge):
  stats = get_stats(ids)
  pair = max(stats, key = stats.get)
  idx = 256 + i
  print(f'merging {pair} into a new token {idx}')
  ids = merge(ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (32, 208) into a new token 256
# merging (208, 190) into a new token 257
# merging (208, 181) into a new token 258
# merging (208, 176) into a new token 259
# merging (209, 130) into a new token 260
# merging (208, 184) into a new token 261
# merging (208, 189) into a new token 262
# merging (209, 129) into a new token 263
# merging (209, 128) into a new token 264
# merging (257, 208) into a new token 265
# merging (10, 208) into a new token 266
# merging (208, 187) into a new token 267
# merging (209, 131) into a new token 268
# merging (209, 139) into a new token 269
# merging (258, 208) into a new token 270
# merging (259, 208) into a new token 271
# merging (209, 140) into a new token 272
# merging (209, 143) into a new token 273
# merging (32, 263) into a new token 274
# merging (256, 178) into a new token 275

# %%
print("tokens lenght:", len(tokens))
print("ids length:", len(ids))
print(f'compression ratio: {len(tokens) / len(ids):.2f}X')
# Out:
# tokens lenght: 1272984
# ids length: 781267
# compression ratio: 1.63X

# %%
vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors = "replace")
  return text

print(decode([128]))
# Out:
# �

# %%
def encode(text):
    tokens = list(text.encode('utf-8'))  # преобразуем текст в байты
    while True:
        # Находим самую частую пару
        pairs = get_stats(tokens)
        if not pairs:
            break
        # Ищем первую пару, которая есть в нашем словаре merges
        pair = None
        for p in pairs:
            if p in merges:
                pair = p
                break
        if not pair:
            break  # нет больше пар для замены
        idx = merges[pair]
        # Заменяем все вхождения пары в tokens
        tokens = merge(tokens, pair, idx)
    return tokens

# %%
print(decode(encode("hello world")))
# Out:
# hello world

# %%
text2 = decode(encode(text))
print(text2 == text)
# Out:
# True

# %%
import regex as re

advanced_russian_pat = re.compile(
    r"""
    # Английские клитики (можно удалить, если работаем только с русским)
    's|'t|'re|'ve|'m|'ll|'d|

    # Русские слова с апострофами и дефисами ("кой-какой", "чудо-юдо")
    (?:[ёЁа-яА-Я]+(?:['-][ёЁа-яА-Я]+)*)|

    # Сокращения ("т.д.", "т.п.", "и.о.")
    (?:[ёЁа-яА-Я]\.){1,3}|

    # Числа (включая числа с разделителями: 1_000_000, 1,234)
    \d+(?:[_,]\d+)*|

    # Остальные последовательности символов (знаки препинания, символы и т.д.)
    [^\sёЁа-яА-Я\d]+|

    # Пробелы (но не перед другим пробелом)
    \s+(?!\S)|

    # Любые оставшиеся пробелы
    \s+
    """,
    re.VERBOSE | re.IGNORECASE
)

re.findall(gpt2pat, text)
# Out:
# ['«',
#  'Внимай',
#  ',',
#  ' что',
#  ' я',
#  ' тебе',
#  ' вещаю',
#  ':',
#  '\n',
#  'Я',
#  ' телом',
#  ' евнух',
#  ',',
#  ' муж',
#  ' душой',
#  '».',
#  ' —',
#  '\n',
#  '«',
#  'Но',
#  ' что',
#  ' ж',
#  ' ты',
#  ' делаешь',
#  ' со',
#  ' мной',
#  '?»',
#  ' —',
#  '\n',
#  '«',
#  'Я',
#  ' тело',
#  ' в',
#  ' душу',
#  ' превращаю',
#  '».',
#  'Злое',
#  ' дитя',
#  ',',
#  ' старик',
#  ' молодой',
#  ',',
#  ' властелин',
#  ' добронравный',
#  ',',
#  '\n',
#  'Гордость',
#  ' внушающий',
#  ' нам',
#  ',',
#  ' шумный',
#  ' заступник',
#  ' любви',
#  '!*',
#  '\n',
#  'Король',
#  ' ходит',
#  ' большими',
#  ' шагами',
#  '\n',
#  'Взад',
#  ' и',
#  ' вперед',
#  ' по',
#  ' палатам',
#  ';',
#  '\n',
#  'Люди',
#  ' спят',
#  ' —',
#  ' королю',
#  ' лишь',
#  ' не',
#  ' спится',
#  ':',
#  '\n',
#  'Короля',
#  ' султан',
#  ' осаждает',
#  ',',
#  '\n',
#  'Голову',
#  ' отсечь',
#  ' ему',
#  ' грозится',
#  '\n',
#  'И',
#  ' в',
#  ' Стамбул',
#  ' отослать',
#  ' ее',
#  ' хочет',
#  '.',
#  '\n',
#  '\n',
#  'Часто',
#  ' он',
#  ' подходит',
#  ' к',
#  ' окошку',
#  ';',
#  '\n',
#  'Не',
#  ' услышит',
#  ' ли',
#  ' какого',
#  ' шума',
#  '?',
#  '\n',
#  'Слышит',
#  ',',
#  ' воет',
#  ' ночная',
#  ' птица',
#  ',',
#  '\n',
#  'Она',
#  ' чует',
#  ' беду',
#  ' неминучу',
#  ',',
#  '\n',
#  'Скоро',
#  ' ей',
#  ' искать',
#  ' новой',
#  ' кровли',
#  '\n',
#  'Для',
#  ' своих',
#  ' птенцов',
#  ' горемычных',
#  '.',
#  '\n',
#  '\n',
#  'Не',
#  ' сова',
#  ' воет',
#  ' в',
#  ' Ключе',
#  '-',
#  'граде',
#  ',',
#  '\n',
#  'Не',
#  ' луна',
#  ' Ключ',
#  '-',
#  'город',
#  ' озаряет',
#  ',',
#  '\n',
#  'В',
#  ' церкви',
#  ' божией',
#  ' гремят',
#  ' барабаны',
#  ',',
#  '\n',
#  'Вся',
#  ' свечами',
#  ' озарена',
#  ' церковь',
#  '.',
#  '\n',
#  '\n',
#  'Но',
#  ' никто',
#  ' барабанов',
#  ' не',
#  ' слышит',
#  ',',
#  '\n',
#  'Никто',
#  ' света',
#  ' в',
#  ' церкви',
#  ' божией',
#  ' не',
#  ' видит',
#  ',',
#  '\n',
#  'Лишь',
#  ' король',
#  ' то',
#  ' слышал',
#  ' и',
#  ' видел',
#  ';',
#  '\n',
#  'Из',
#  ' палат',
#  ' своих',
#  ' он',
#  ' выходит',
#  '\n',
#  'И',
#  ' идет',
#  ' один',
#  ' в',
#  ' божию',
#  ' церковь',
#  '.',
#  '\n',
#  '\n',
#  'Стал',
#  ' на',
#  ' паперти',
#  ',',
#  ' дверь',
#  ' отворяет',
#  '...',
#  '\n',
#  'Ужасом',
#  ' в',
#  ' нем',
#  ' замерло',
#  ' сердце',
#  ',',
#  '\n',
#  'Но',
#  ' великую',
#  ' творит',
#  ' он',
#  ' молитву',
#  '\n',
#  'И',
#  ' спокойно',
#  ' в',
#  ' церковь',
#  ' божию',
#  ' входит',
#  '.',
#  '\n',
#  '\n',
#  'Тут',
#  ' он',
#  ' видит',
#  ' чудное',
#  ' виденье',
#  ':',
#  '\n',
#  'На',
#  ' помосте',
#  ' валяются',
#  ' трупы',
#  ',',
#  '\n',
#  'Между',
#  ' ими',
#  ' хлещет',
#  ' кровь',
#  ' ручьями',
#  ',',
#  '\n',
#  'Как',
#  ' потоки',
#  ' осени',
#  ' дождливой',
#  '.',
#  '\n',
#  'Кровь',
#  ' по',
#  ' щиколку',
#  '**',
#  ' ему',
#  ' досягает',
#  '...',
#  '\n',
#  '\n',
#  'Горе',
#  '!',
#  ' в',
#  ' церкви',
#  ' турки',
#  ' и',
#  ' татары',
#  '\n',
#  'И',
#  ' предатели',
#  ',',
#  ' враги',
#  ' богумилы',
#  '.***',
#  '\n',
#  'На',
#  ' амвоне',
#  ' сам',
#  ' султан',
#  ' безбожный',
#  ',',
#  '\n',
#  'Держит',
#  ' он',
#  ' на',
#  '-',
#  'голо',
#  ' саблю',
#  ',',
#  '\n',
#  'Кровь',
#  ' по',
#  ' сабле',
#  ' свежая',
#  ' струится',
#  '\n',
#  'С',
#  ' вострия',
#  ' до',
#  ' самой',
#  ' рукояти',
#  '.',
#  '\n',
#  '\n',
#  'Короля',
#  ' незапный',
#  ' обнял',
#  ' холод',
#  ':',
#  '\n',
#  'Тут',
#  ' же',
#  ' видит',
#  ' он',
#  ' отца',
#  ' и',
#  ' брата',
#  '.',
#  '\n',
#  'Пред',
#  ' султаном',
#  ' старик',
#  ' бедный',
#  ' справа',
#  ',',
#  '\n',
#  'Униженно',
#  ' стоя',
#  ' на',
#  ' коленах',
#  ',',
#  '\n',
#  'Подает',
#  ' ему',
#  ' свою',
#  ' корону',
#  ';',
#  '\n',
#  'Слева',
#  ',',
#  ' также',
#  ' стоя',
#  ' на',
#  ' коленах',
#  ',',
#  '\n',
#  'Его',
#  ' сын',
#  ',',
#  ' Радивой',
#  ' окаянный',
#  ',',
#  '\n',
#  'Басурманскою',
#  ' чалмою',
#  ' покрытый',
#  '\n',
#  '(',
#  'С',
#  ' тою',
#  ' самою',
#  ' веревкою',
#  ',',
#  ' которой',
#  '\n',
#  'Удавил',
#  ' он',
#  ' несчастного',
#  ' старца',
#  '),',
#  '\n',
#  'Край',
#  ' полы',
#  ' у',
#  ' султана',
#  ' целует',
#  ',',
#  '\n',
#  'Как',
#  ' холоп',
#  ',',
#  ' наказанный',
#  ' фалангой',
#  '.****',
#  '\n',
#  '\n',
#  'И',
#  ' султан',
#  ' безбожный',
#  ',',
#  ' усмехаясь',
#  ',',
#  '\n',
#  'Взял',
#  ' корону',
#  ',',
#  ' растоптал',
#  ' ногами',
#  ',',
#  '\n',
#  'И',
#  ' промолвил',
#  ' потом',
#  ' Радивою',
#  ':',
#  '\n',
#  '«',
#  'Будь',
#  ' над',
#  ' Боснией',
#  ' моей',
#  ' ты',
#  ' властелином',
#  ',',
#  '\n',
#  'Для',
#  ' гяур',
#  '-',
#  'християн',
#  ' беглербеем',
#  '».*****',
#  '\n',
#  'И',
#  ' отступник',
#  ' бил',
#  ' челом',
#  ' султану',
#  ',',
#  '\n',
#  'Трижды',
#  ' пол',
#  ' окровавленный',
#  ' целуя',
#  '.',
#  '\n',
#  '\n',
#  'И',
#  ' султан',
#  ' прислужников',
#  ' кликнул',
#  '\n',
#  'И',
#  ' сказал',
#  ':',
#  ' «',
#  'Дать',
#  ' кафтан',
#  ' Радивою',
#  '!******',
#  '\n',
#  'Не',
#  ' бархатный',
#  ' кафтан',
#  ',',
#  ' не',
#  ' парчевый',
#  ',',
#  '\n',
#  'А',
#  ' содрать',
#  ' на',
#  ' кафтан',
#  ' Радивоя',
#  '\n',
#  'Кожу',
#  ' с',
#  ' брата',
#  ' его',
#  ' родного',
#  '».',
#  '\n',
#  'Бусурмане',
#  ' на',
#  ' короля',
#  ' наскочили',
#  ',',
#  '\n',
#  'До',
#  '-',
#  'нага',
#  ' всего',
#  ' его',
#  ' раздели',
#  ',',
#  '\n',
#  'Атаганом',
#  ' ему',
#  ' кожу',
#  ' вспороли',
#  ',',
#  '\n',
#  'Стали',
#  ' драть',
#  ' руками',
#  ' и',
#  ' зубами',
#  ',',
#  '\n',
#  'Обнажили',
#  ' мясо',
#  ' и',
#  ' жилы',
#  ',',
#  '\n',
#  'И',
#  ' до',
#  ' самых',
#  ' костей',
#  ' ободрали',
#  ',',
#  '\n',
#  'И',
#  ' одели',
#  ' кожею',
#  ' Радивоя',
#  '.',
#  '\n',
#  '\n',
#  'Громко',
#  ' мученик',
#  ' господу',
#  ' взмолился',
#  ':',
#  '\n',
#  '«',
#  'Прав',
#  ' ты',
#  ',',
#  ' боже',
#  ',',
#  ' меня',
#  ' наказуя',
#  '!',
#  '\n',
#  'Плоть',
#  ' мою',
#  ' предай',
#  ' на',
#  ' растерзанье',
#  ',',
#  '\n',
#  'Лишь',
#  ' помилуй',
#  ' мне',
#  ' душу',
#  ',',
#  ' Иисусе',
#  '!»',
#  '\n',
#  '\n',
#  'При',
#  ' сем',
#  ' имени',
#  ' церковь',
#  ' задрожала',
#  ',',
#  '\n',
#  'Всё',
#  ' внезапно',
#  ' утихнуло',
#  ',',
#  ' померкло',
#  ',',
#  ' —',
#  '\n',
#  'Всё',
#  ' исчезло',
#  ' —',
#  ' будто',
#  ' не',
#  ' бывало',
#  '.',
#  '\n',
#  '\n',
#  'И',
#  ' король',
#  ' ощупью',
#  ' в',
#  ' потемках',
#  '\n',
#  'Коё',
#  '-',
#  'как',
#  ' до',
#  ' двери',
#  ' добрался',
#  '\n',
#  'И',
#  ' с',
#  ' молитвою',
#  ' на',
#  ' улицу',
#  ' вышел',
#  '.',
#  '\n',
#  '\n',
#  'Было',
#  ' тихо',
#  '.',
#  ' С',
#  ' высокого',
#  ' неба',
#  '\n',
#  'Город',
#  ' белый',
#  ' луна',
#  ' озаряла',
#  '.',
#  '\n',
#  'Вдруг',
#  ' взвилась',
#  ' из',
#  '-',
#  'за',
#  ' города',
#  ' бомба',
#  ',*******',
#  '\n',
#  'И',
#  ' пошли',
#  ' бусурмане',
#  ' на',
#  ' приступ',
#  '.',
#  '\n',
#  '<',
#  'note',
#  '>*',
#  ' Фома',
#  ' I',
#  ' был',
#  ' тайно',
#  ' умерщвлен',
#  ' своими',
#  ' двумя',
#  ' сыновьями',
#  ' Стефаном',
#  ' и',
#  ' Радивоем',
#  ' в',
#  ' 1460',
#  ' году',
#  '.',
#  ' Стефан',
#  ' ему',
#  ' наследовал',
#  '.',
#  ' Радивой',
#  ',',
#  ' негодуя',
#  ' на',
#  ' брата',
#  ' за',
#  ' похищение',
#  ' власти',
#  ',',
#  ' разгласил',
#  ' ужасную',
#  ' тайну',
#  ' и',
#  ' бежал',
#  ' в',
#  ' Турцию',
#  ' к',
#  ' Магомету',
#  ' II',
#  '.',
#  ' Стефан',
#  ',',
#  ' по',
#  ' внушению',
#  ' папского',
#  ' легата',
#  ',',
#  ' решился',
#  ' воевать',
#  ' с',
#  ' турками',
#  '.',
#  ' Он',
#  ' был',
#  ' побежден',
#  ' и',
#  ' бежал',
#  ' в',
#  ' Ключ',
#  '-',
#  'город',
#  ',',
#  ' где',
#  ' Магомет',
#  ' осадил',
#  ' его',
#  '.',
#  ' Захваченный',
#  ' в',
#  ' плен',
#  ',',
#  ' он',
#  ' не',
#  ' согласился',
#  ' принять',
#  ' магометанскую',
#  ' веру',
#  ',',
#  ' и',
#  ' с',
#  ' него',
#  ' содрали',
#  ' кожу',
#  '.',
#  '\n',
#  '**',
#  ' Щиколодка',
#  ',',
#  ' по',
#  ' московскому',
#  ' наречию',
#  ' щиколка',
#  '.',
#  '\n',
#  '***',
#  ' Так',
#  ' называют',
#  ' себя',
#  ' некоторые',
#  ' иллирийские',
#  ' раскольники',
#  '.',
#  '\n',
#  '****',
#  ' Фаланга',
#  ',',
#  ' палочные',
#  ' удары',
#  ' по',
#  ' пятам',
#  '.',
#  '\n',
#  '*****',
#  ' Радивой',
#  ' никогда',
#  ' не',
#  ' имел',
#  ' этого',
#  ' сана',
#  ';',
#  ' и',
#  ' все',
#  ' члены',
#  ' королевского',
#  ' семейства',
#  ' истреблены',
#  ' были',
#  ' султаном',
#  '.',
#  '\n',
#  '******',
#  ' Кафтан',
#  ',',
#  ' обыкновенный',
#  ' подарок',
#  ' султанов',
#  '.',
#  '\n',
#  '*******',
#  ' Анахронизм',
#  '.</',
#  'note',
#  '>',
#  'Не',
#  ' дай',
#  ' мне',
#  ' бог',
#  ' сойти',
#  ' с',
#  ' ума',
#  '.',
#  '\n',
#  'Нет',
#  ',',
#  ' легче',
#  ' посох',
#  ' и',
#  ' сума',
#  ';',
#  '\n',
#  'Нет',
#  ',',
#  ' легче',
#  ' труд',
#  ' и',
#  ' глад',
#  '.',
#  '\n',
#  'Не',
#  ' то',
#  ',',
#  ' чтоб',
#  ' разумом',
#  ' моим',
#  '\n',
#  'Я',
#  ' дорожил',
#  ';',
#  ' не',
#  ' то',
#  ',',
#  ' чтоб',
#  ' с',
#  ' ним',
#  '\n',
#  'Расстаться',
#  ' был',
#  ' не',
#  ' рад',
#  ':',
#  '\n',
#  '\n',
#  'Когда',
#  ' б',
#  ' оставили',
#  ' меня',
#  '\n',
#  'На',
#  ' воле',
#  ',',
#  ' как',
#  ' бы',
#  ' резво',
#  ' я',
#  '\n',
#  'Пустился',
#  ' в',
#  ' темный',
#  ' лес',
#  '!',
#  '\n',
#  'Я',
#  ' пел',
#  ' бы',
#  ' в',
#  ' пламенном',
#  ' бреду',
#  ',',
#  '\n',
#  'Я',
#  ' забывался',
#  ' бы',
#  ' в',
#  ' чаду',
#  '\n',
#  'Нестройных',
#  ',',
#  ' чудных',
#  ' грез',
#  '.',
#  '\n',
#  '\n',
#  'И',
#  ' я',
#  ' б',
#  ' заслушивался',
#  ' волн',
#  ',',
#  '\n',
#  'И',
#  ' я',
#  ' глядел',
#  ' бы',
#  ',',
#  ' счастья',
#  ' полн',
#  ',',
#  '\n',
#  'В',
#  ' пустые',
#  ' небеса',
#  ';',
#  '\n',
#  'И',
#  ' силен',
#  ',',
#  ' волен',
#  ' был',
#  ' бы',
#  ' я',
#  ',',
#  '\n',
#  'Как',
#  ' вихорь',
#  ',',
#  ' роющий',
#  ' поля',
#  ',',
#  '\n',
#  'Ломающий',
#  ' леса',
#  '.',
#  '\n',
#  '\n',
#  'Да',
#  ' вот',
#  ' беда',
#  ':',
#  ' сойди',
#  ' с',
#  ' ума',
#  ',',
#  '\n',
#  'И',
#  ' страшен',
#  ' будешь',
#  ' как',
#  ' чума',
#  ',',
#  '\n',
#  'Как',
#  ' раз',
#  ' тебя',
#  ' запрут',
#  ',',
#  '\n',
#  'Посадят',
#  ' на',
#  ' цепь',
#  ' дурака',
#  '\n',
#  'И',
#  ' сквозь',
#  ' решетку',
#  ' как',
#  ' зверка',
#  '\n',
#  'Дразнить',
#  ' тебя',
#  ' придут',
#  '.',
#  '\n',
#  '\n',
#  'А',
#  ' ночью',
#  ' слышать',
#  ' буду',
#  ' я',
#  '\n',
#  'Не',
#  ' голос',
#  ' яркий',
#  ' соловья',
#  ',',
#  '\n',
#  'Не',
#  ' шум',
#  ' глухой',
#  ' дубров',
#  ' —',
#  '\n',
#  'А',
#  ' крик',
#  ' товарищей',
#  ' моих',
#  '\n',
#  'Да',
#  ' брань',
#  ' смотрителей',
#  ' ночных',
#  ',',
#  '\n',
#  'Да',
#  ' визг',
#  ',',
#  ' да',
#  ' звон',
#  ' оков',
#  '.<',
#  'epigraph',
#  '>',
#  'Tel',
#  ' j',
#  '’',
#  'étais',
#  ' autrefois',
#  ' et',
#  ' tel',
#  ' je',
#  ' suis',
#  ' encor',
#  '.</',
#  'epigraph',
#  ...]

# %%
example = """
for i in range(1, 101):
    if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
"""
print(re.findall(gpt2pat, example))
# Out:
# ['\n', 'for', ' i', ' in', ' range', '(', '1', ',', ' 101', '):', '\n   ', ' if', ' i', ' %', ' 3', ' ==', ' 0', ' and', ' i', ' %', ' 5', ' ==', ' 0', ':', '\n       ', ' print', '("', 'FizzBuzz', '")', '\n   ', ' elif', ' i', ' %', ' 3', ' ==', ' 0', ':', '\n       ', ' print', '("', 'Fizz', '")', '\n   ', ' elif', ' i', ' %', ' 5', ' ==', ' 0', ':', '\n       ', ' print', '("', 'Buzz', '")', '\n   ', ' else', ':', '\n       ', ' print', '(', 'i', ')', '\n']

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import zipfile
import os

zip_path = '/content/texts.zip'

extract_dir = 'extract_dir'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall(extract_dir)

txt_files = [f for f in os.listdir(extract_dir) if f.endswith('.txt')]

text = ''
for file in txt_files:
  file_path = os.path.join(extract_dir, file)
  with open(file_path, 'r', encoding='utf-8') as f:
    text += f.read()

tokens = list(map(int, text.encode("utf-8")))

def get_stats(tokens):
    counts = {}
    for i in range(len(tokens)-1):
        pair = (tokens[i], tokens[i+1])
        counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(ids, pair, idx):
  newids = []
  i = 0
  while i < len(ids):
    if i < len(ids) - 1 and ids[i] == pair[0] and ids[i+1] == pair[1]:
      newids.append(idx)
      i += 2
    else:
      newids.append(ids[i])
      i += 1
  return newids

vocab_size = 276
num_merge = vocab_size - 256
ids = list(tokens)

merges = {}
for i in range(num_merge):
  stats = get_stats(ids)
  pair = max(stats, key = stats.get)
  idx = 256 + i
  print(f'merging {pair} into a new token {idx}')
  ids = merge(ids, pair, idx)
  merges[pair] = idx

print("tokens lenght:", len(tokens))
print("ids length:", len(ids))
print(f'compression ratio: {len(tokens) / len(ids):.2f}X')

vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors = "replace")
  return text

def encode(text):
    tokens = list(text.encode('utf-8'))  # преобразуем текст в байты
    while True:
        # Находим самую частую пару
        pairs = get_stats(tokens)
        if not pairs:
            break
        # Ищем первую пару, которая есть в нашем словаре merges
        pair = None
        for p in pairs:
            if p in merges:
                pair = p
                break
        if not pair:
            break  # нет больше пар для замены
        idx = merges[pair]
        # Заменяем все вхождения пары в tokens
        tokens = merge(tokens, pair, idx)
    return tokens

text2 = decode(encode(text))
print(text2 == text)
# Out:
# merging (32, 208) into a new token 256
# merging (208, 190) into a new token 257
# merging (208, 181) into a new token 258
# merging (208, 176) into a new token 259
# merging (209, 130) into a new token 260
# merging (208, 184) into a new token 261
# merging (208, 189) into a new token 262
# merging (209, 129) into a new token 263
# merging (209, 128) into a new token 264
# merging (257, 208) into a new token 265
# merging (10, 208) into a new token 266
# merging (208, 187) into a new token 267
# merging (209, 131) into a new token 268
# merging (209, 139) into a new token 269
# merging (258, 208) into a new token 270
# merging (259, 208) into a new token 271
# merging (209, 140) into a new token 272
# merging (209, 143) into a new token 273
# merging (32, 263) into a new token 274
# merging (256, 178) into a new token 275
# tokens lenght: 1272984
# ids length: 781267
# compression ratio: 1.63X
# True

# %%
import regex as re
import copy
from itertools import chain
import torch
import torch.nn as nn
from torch.nn import functional as F
import zipfile
import os

zip_path = '/content/texts.zip'

extract_dir = 'extract_dir'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall(extract_dir)

txt_files = [f for f in os.listdir(extract_dir) if f.endswith('.txt')]

text = ''
for file in txt_files:
  file_path = os.path.join(extract_dir, file)
  with open(file_path, 'r', encoding='utf-8') as f:
    text += f.read()

advanced_russian_pat = re.compile(
    r"""
    # Английские клитики (можно удалить, если работаем только с русским)
    's|'t|'re|'ve|'m|'ll|'d|

    # Русские слова с апострофами и дефисами ("кой-какой", "чудо-юдо")
    (?:[ёЁа-яА-Я]+(?:['-][ёЁа-яА-Я]+)*)|

    # Сокращения ("т.д.", "т.п.", "и.о.")
    (?:[ёЁа-яА-Я]\.){1,3}|

    # Числа (включая числа с разделителями: 1_000_000, 1,234)
    \d+(?:[_,]\d+)*|

    # Остальные последовательности символов (знаки препинания, символы и т.д.)
    [^\sёЁа-яА-Я\d]+|

    # Пробелы (но не перед другим пробелом)
    \s+(?!\S)|

    # Любые оставшиеся пробелы
    \s+
    """,
    re.VERBOSE | re.IGNORECASE
)

tokens = re.findall(advanced_russian_pat, text)

tton = [] #tokens to numbers size: number tokens x size tokens
for i in range(len(tokens)):
  tton.append(list(map(int, tokens[i].encode("utf-8"))))

def get_stats(tton):
    counts = {}
    for i in range(len(tton)):
      for j in range(len(tton[i])-1):
          pair = (tton[i][j], tton[i][j+1])
          counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(tton, pair, idx):
  newids = []

  for i in range(len(tton)):
    newids.append([])
    j = 0
    while j < len(tton[i]):
      if j < len(tton[i]) - 1 and tton[i][j] == pair[0] and tton[i][j+1] == pair[1]:
        newids[i].append(idx)
        j += 2
      else:
        newids[i].append(tton[i][j])
        j += 1
  return newids

vocab_size = 276
num_merge = vocab_size - 256
ids = copy.deepcopy(tton)

merges = {}
for i in range(num_merge):
  stats = get_stats(ids)
  pair = max(stats, key = stats.get)
  idx = 256 + i
  print(f'merging {pair} into a new token {idx}')
  ids = merge(ids, pair, idx)
  merges[pair] = idx

vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors = "replace")
  return text

def encode(text):

    tokens = re.findall(advanced_russian_pat, text)
    tton = [] #tokens to numbers size: number tokens x size tokens
    for i in range(len(tokens)):
      tton.append(list(map(int, tokens[i].encode("utf-8"))))

    while True:
        # Находим самую частую пару
        pairs = get_stats(tton)
        if not pairs:
            break
        # Ищем первую пару, которая есть в нашем словаре merges
        pair = None
        for p in pairs:
            if p in merges:
                pair = p
                break
        if not pair:
            break  # нет больше пар для замены
        idx = merges[pair]
        # Заменяем все вхождения пары в tokens
        tton = merge(tton, pair, idx)

    return list(chain.from_iterable(tton))

text2 = decode(encode(text))
print(text2 == text)
# Out:
# merging (208, 190) into a new token 256
# merging (208, 181) into a new token 257
# merging (208, 176) into a new token 258
# merging (208, 189) into a new token 259
# merging (208, 184) into a new token 260
# merging (209, 130) into a new token 261
# merging (256, 208) into a new token 262
# merging (209, 129) into a new token 263
# merging (209, 128) into a new token 264
# merging (208, 187) into a new token 265
# merging (208, 178) into a new token 266
# merging (209, 131) into a new token 267
# merging (208, 180) into a new token 268
# merging (208, 188) into a new token 269
# merging (209, 139) into a new token 270
# merging (208, 186) into a new token 271
# merging (209, 140) into a new token 272
# merging (208, 191) into a new token 273
# merging (209, 143) into a new token 274
# merging (208, 177) into a new token 275
# True

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import zipfile
import os

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

zip_path = '/content/texts.zip'

extract_dir = 'extract_dir'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
  zip_ref.extractall(extract_dir)

txt_files = [f for f in os.listdir(extract_dir) if f.endswith('.txt')]

text = ''
for file in txt_files:
  file_path = os.path.join(extract_dir, file)
  with open(file_path, 'r', encoding='utf-8') as f:
    text += f.read()

# Встраиваем токенайзер BPE c регулярными выражениями для русского языка
# ----------------------------------------------------------------------------
advanced_russian_pat = re.compile(
    r"""
    # Английские клитики (можно удалить, если работаем только с русским)
    's|'t|'re|'ve|'m|'ll|'d|

    # Русские слова с апострофами и дефисами ("кой-какой", "чудо-юдо")
    (?:[ёЁа-яА-Я]+(?:['-][ёЁа-яА-Я]+)*)|

    # Сокращения ("т.д.", "т.п.", "и.о.")
    (?:[ёЁа-яА-Я]\.){1,3}|

    # Числа (включая числа с разделителями: 1_000_000, 1,234)
    \d+(?:[_,]\d+)*|

    # Остальные последовательности символов (знаки препинания, символы и т.д.)
    [^\sёЁа-яА-Я\d]+|

    # Пробелы (но не перед другим пробелом)
    \s+(?!\S)|

    # Любые оставшиеся пробелы
    \s+
    """,
    re.VERBOSE | re.IGNORECASE
)

tokens = re.findall(advanced_russian_pat, text)

tton = [] #tokens to numbers size: (number tokens, size tokens)
for i in range(len(tokens)):
  tton.append(list(map(int, tokens[i].encode("utf-8"))))

def get_stats(tton):
    counts = {}
    for i in range(len(tton)):
      for j in range(len(tton[i])-1):
          pair = (tton[i][j], tton[i][j+1])
          counts[pair] = counts.get(pair, 0) + 1
    return counts

def merge(tton, pair, idx):
  newids = []

  for i in range(len(tton)):
    newids.append([])
    j = 0
    while j < len(tton[i]):
      if j < len(tton[i]) - 1 and tton[i][j] == pair[0] and tton[i][j+1] == pair[1]:
        newids[i].append(idx)
        j += 2
      else:
        newids[i].append(tton[i][j])
        j += 1
  return newids

vocab_size = 276
num_merge = vocab_size - 256
ids = copy.deepcopy(tton)

merges = {}
for i in range(num_merge):
  stats = get_stats(ids)
  pair = max(stats, key = stats.get)
  idx = 256 + i
  print(f'merging {pair} into a new token {idx}')
  ids = merge(ids, pair, idx)
  merges[pair] = idx

vocab = {idx: bytes([idx]) for idx in range(256)}
for (p0, p1), idx in merges.items():
  vocab[idx] = vocab[p0] + vocab[p1]

def decode(ids):
  tokens = b"".join(vocab[idx] for idx in ids)
  text = tokens.decode("utf-8", errors = "replace")
  return text

def encode(text):

    tokens = re.findall(advanced_russian_pat, text)
    tton = [] #tokens to numbers size: (number tokens, size tokens)
    for i in range(len(tokens)):
      tton.append(list(map(int, tokens[i].encode("utf-8"))))

    while True:
        pairs = get_stats(tton)
        if not pairs:
            break
        pair = None
        for p in pairs:
            if p in merges:
                pair = p
                break
        if not pair:
            break
        idx = merges[pair]
        tton = merge(tton, pair, idx)

    return list(chain.from_iterable(tton))

text2 = decode(encode(text))
print(text2 == text)
# ----------------------------------------------------------------------------

## here are all the unique characters that occur in this text
#chars = sorted(list(set(text)))
#vocab_size = len(chars)
## create a mapping from characters to integers
#stoi = { ch:i for i,ch in enumerate(chars) }
#itos = { i:ch for i,ch in enumerate(chars) }
#encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
#decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# merging (32, 208) into a new token 256
# merging (208, 190) into a new token 257
# merging (208, 181) into a new token 258
# merging (208, 176) into a new token 259
# merging (209, 130) into a new token 260
# merging (208, 184) into a new token 261
# merging (208, 189) into a new token 262
# merging (209, 129) into a new token 263
# merging (209, 128) into a new token 264
# merging (257, 208) into a new token 265
# merging (10, 208) into a new token 266
# merging (208, 187) into a new token 267
# merging (209, 131) into a new token 268
# merging (209, 139) into a new token 269
# merging (258, 208) into a new token 270
# merging (259, 208) into a new token 271
# merging (209, 140) into a new token 272
# merging (209, 143) into a new token 273
# merging (32, 263) into a new token 274
# merging (256, 178) into a new token 275
# tokens lenght: 1272984
# ids length: 781267
# compression ratio: 1.63X
# True
# 0.236948 M parameters
# step 0: train loss 5.7695, val loss 5.7713
# step 100: train loss 2.8858, val loss 2.9952
# step 200: train loss 2.6287, val loss 2.6801
# step 300: train loss 2.5597, val loss 2.5922
# step 400: train loss 2.5069, val loss 2.5401
# step 500: train loss 2.4701, val loss 2.4929
# step 600: train loss 2.4242, val loss 2.4546
# step 700: train loss 2.3858, val loss 2.4183
# step 800: train loss 2.3776, val loss 2.4357
# step 900: train loss 2.3280, val loss 2.3694
# step 1000: train loss 2.3154, val loss 2.3523
# step 1100: train loss 2.2961, val loss 2.3386
# step 1200: train loss 2.2659, val loss 2.3218
# step 1300: train loss 2.2675, val loss 2.3102
# step 1400: train loss 2.2486, val loss 2.2819
# step 1500: train loss 2.2384, val loss 2.2747
# step 1600: train loss 2.2098, val loss 2.2623
# step 1700: train loss 2.2173, val loss 2.2522
# step 1800: train loss 2.1948, val loss 2.2340
# step 1900: train loss 2.1821, val loss 2.2216
# step 2000: train loss 2.1703, val loss 2.2055
# step 2100: train loss 2.1597, val loss 2.1901
# step 2200: train loss 2.1518, val loss 2.1894
# step 2300: train loss 2.1303, val loss 2.1776
# step 2400: train loss 2.1247, val loss 2.1704
# step 2500: train loss 2.1135, val loss 2.1483
# step 2600: train loss 2.1077, val loss 2.1486
# step 2700: train loss 2.1088, val loss 2.1369
# step 2800: train loss 2.0939, val loss 2.1386
# step 2900: train loss 2.0973, val loss 2.1368
# step 3000: train loss 2.0792, val loss 2.1171
# step 3100: train loss 2.0710, val loss 2.1068
# step 3200: train loss 2.0494, val loss 2.0967
# step 3300: train loss 2.0512, val loss 2.0974
# step 3400: train loss 2.0553, val loss 2.0959
# step 3500: train loss 2.0358, val loss 2.0700
# step 3600: train loss 2.0377, val loss 2.0829
# step 3700: train loss 2.0256, val loss 2.0732
# step 3800: train loss 2.0276, val loss 2.0568
# step 3900: train loss 2.0162, val loss 2.0571
# step 4000: train loss 2.0199, val loss 2.0556
# step 4100: train loss 2.0060, val loss 2.0542
# step 4200: train loss 2.0010, val loss 2.0452
# step 4300: train loss 1.9923, val loss 2.0301
# step 4400: train loss 1.9819, val loss 2.0456
# step 4500: train loss 1.9692, val loss 2.0266
# step 4600: train loss 1.9814, val loss 2.0408
# step 4700: train loss 1.9695, val loss 2.0249
# step 4800: train loss 1.9763, val loss 2.0191
# step 4900: train loss 1.9751, val loss 2.0316
# step 4999: train loss 1.9651, val loss 2.0209
# е недадось томною;
# И воле, режных доброгила досил
# В обужет море и мучит;
# Разднь вечною моедной
# И ты, вечною завет.
# Верню от развалебной увою?
# Wсвею, у е�тей,
# Где улом, и слезаннысодиль игреит,
# Чтоб тих недменной злалемен!
# А полосает юносит:
# Увакут, мину приная Эухуросов</speaker>бвит разговор<н> веся одна,
# [Вижелу мо хосранил:
# Ток, оплоним путехом
# Умяркому лессви* вечной сникое кровкома,
# Отямную считья стихан
# Лет, усакомщенннияю цуром
# Хразати межит пустымного увеструг,
# Зостарежескикусь брожежною,
# Хрюду клюс
# Гдорши, не лиродицанься,
# Паристотой скелью?
# Но покли посотит дарожные заросор.
# Но косладно, с мудель и вравам.
#
# Три поэведе вы чистой обита в него иминь и вело».Велирой,
# Сне с прижесал оюторо видит.
# Ину бутью коне моей болею
# И в инусть, пототите.
# «Срезлив, и спережит,
# Паомить его в заблат,
# Евет и в тегонько бещенике,
# Она продут зарита.
# Приявски разуной
# Я владиит ты, отлые беду,
# Осовой прочутит — поминый
# �»таящал руезья,
# Не вдрулью врезку песи нагрита..
# Гь грозий рездой ими,
# Оградося утесяно страю
# Угоры пекола,
# Пред с, бого леса критком грожнья
# Лукой, сторя и лирен у укогор надеждуй!
# Свой нагошико. лесо,
# И в мнич заре.?>
# В млогобни Самучестье
# То, ли, <сной>
# Хорвит множеной! Свездникого голе
# Ргосутьной хочтом, застой,
# Иль и гиль пит, — е? мни,
# Вы же золет корносошою,
# Возитят?
# Аны ты желе, пирный,
# Дверзящ, Мосселуюся,
# Стаку мой — моложены
# Пергест
# Солитежный понежим
# Что в мозираяем он.
# А их видим царители высочи.
# Снавнуми гнел подолуют ой,
# В брез уей,
# Ссел усаямальт,
# Ви зоризя, шум местом,
# Помилой елою паш каремител,
# Ни в трестной их поп пали тело кляной
# Долме�и печальный.ни ончиродь
# Ти пустой осто омно мой,
# Хне пустимна времеке моровый напрозныбариз
# Зарьтуник ус)ротовон.,
# Лилетный рождо золенен?
# На гел литвой осудальные далы
# Братилуй
# Бизятну гравняе и слезветал,
# И проклизнив от Еливленкий
# Я благостом своободая, рой,
# У на в ней беньх молодой;
# С
